// %% [markdown]
// # 2 Easy Wins
// ##### **Author: Adam Gatt**
//
// Later notebooks will cover more advance topics but this one aims to show off simple new language features that you should be able to immediately benefit from with little/no trade-off. Many revolve around enforcing correctness, to help remove some classes of bugs before they have a chance to happen.
//
// The [clang-tidy](https://clang.llvm.org/extra/clang-tidy/) linter will be able to make suggestions about many of these language features, pointing out situation where they can be used. With some care and manual review, you can even run the linter over an entire existing codebase and have the suggestions applied automatically.

// %% [markdown]
// ## override

// %% [markdown]
// How come the duck below fails to realise it can quack?

// %%
#include <iostream>

class Bird {
    public:
    virtual void makeNoise() const {
        std::cout << "Chirp!" << std::endl;
    }
};

class Duck : public Bird {
    public:
    virtual void makeNoise() {
        std:: cout << "Quack!" << std::endl;
    }
};

Bird* daffy = new Duck();

daffy->makeNoise();
// Out:
// Chirp!

// %% [markdown]
// It's because the two `makeNoise()` functions aren't the same! Because one is const and the other isn't, they count as having different signatures. This means the derived class isn't overriding the makeNoise in the base class; the two methods don't occupy the same entry in the vtable.
//
// Constness is a subtle way this bug can occur, but it can also be caused by a typo in the method name or differences in parameter types.
//
// Because both the base and overridden methods use the same syntax (beginning `virtual` annotation), the compiler doesn't have a clear way to know that `Duck::makeNoise` is meant to be an overridden method instead of starting its own base virtual method. `override` is a new annotation to add to the overriding method and make it clear to the compiler. When a method is marked `override` the compiler will search for a matching base virtual method to ensure it exists, and will throw a compilation error if one cannot be found.
//
// As an added benefit it also makes the intention clear to the human reader.

// %%
class Turkey : public Bird {
    public:
    virtual void makeNoise() override {
        std:: cout << "Gobble!" << std::endl;
    }
};
// Out:
// input_line_9:3:18: error: 'makeNoise' marked 'override' but does not override any member functions
//     virtual void makeNoise() override {
//                  ^
// Interpreter Error:

// %% [markdown]
// ## nullptr

// %% [markdown]
// `nullptr` is a Modern C++ keywork for the null reference, where in the past you might have used `0` or `NULL` (often #defined to be 0). The advantage of nullptr is that it has its own type (`std::nullptr_t`), whereas the `int` type of NULL can allow for subtle bugs or ambiguities, especially in constructors and overloaded functions. In the best-case scenario the compiler will notice the ambiguity with a warning or error, in the worst-case you may have a subtle logic error.

// %%
class Colour {    
    public:
    int rgbCode;
    
    // Specify the rgb code directly
    Colour(int rgbCode) : rgbCode(rgbCode) { }
    
    // Copy the rgb code from another Colour
    Colour(const Colour* cloneSrc) {
        if (cloneSrc != NULL) {
            rgbCode = cloneSrc->rgbCode;
        }
    }
}

// %%
// Which constructor will be called?

Colour col1(NULL);
// Out:
// input_line_11:3:8: error: call to constructor of '__cling_N54::Colour' is ambiguous
// Colour col1(NULL);
//        ^    ~~~~
// input_line_10:6:5: note: candidate constructor
//     Colour(int rgbCode) : rgbCode(rgbCode) { }
//     ^
// input_line_10:9:5: note: candidate constructor
//     Colour(const Colour* cloneSrc) {
//     ^
// input_line_10:1:7: note: candidate is the implicit copy constructor
// class Colour {
//       ^
// input_line_10:1:7: note: candidate is the implicit move constructor
// Interpreter Error:

// %%
Colour col2(nullptr);

// %% [markdown]
// Notice the constructor executing correctly instead of trying to dereference nullptr. This is because the guard clause `if (cloneSrc != NULL)` still performed its job. The new keyword enjoys strong interoperability with existing legacy code as the rules for comparing nullptr and NULL have been well-defined to produce intuitive results.

// %%
bool comparisons[] {
    nullptr == nullptr,
    nullptr != nullptr,
    nullptr == NULL,
    nullptr != NULL,
    nullptr == 0,
    nullptr != 0,
    nullptr ? true : false
};

comparisons
// Out:
// input_line_13:5:13: warning: comparison between NULL and non-pointer ('nullptr_t' and NULL) [-Wnull-arithmetic]
//     nullptr == NULL,
//     ~~~~~~~ ^  ~~~~
// input_line_13:6:13: warning: comparison between NULL and non-pointer ('nullptr_t' and NULL) [-Wnull-arithmetic]
//     nullptr != NULL,
//     ~~~~~~~ ^  ~~~~
// input_line_13:9:5: warning: implicit conversion of nullptr constant to 'bool' [-Wnull-conversion]
//     nullptr ? true : false
//     ^~~~~~~ ~
//     false
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:137:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_istream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/istream:974:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_istream<char> &> >,
//       std::__is_convertible_to_basic_istream<std::basic_istream<char> &>, std::__is_extractable<std::basic_istream<char> &, std::complex<float> &, void> >' requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Istream>>,
//                        ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/complex:1528:28: note: while substituting deduced template arguments into function template 'operator>>' [with _Istream = std::basic_istream<char> &, _Tp = std::complex<float> &]
//   extern template istream& operator>>(istream&, complex<float>&);
//                            ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:137:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/ostream:685:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >,
//       std::__is_convertible_to_basic_ostream<std::basic_ostream<char> &>, std::__is_insertable<std::basic_ostream<char> &, const std::complex<float> &, void> >' requested
//       here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Ostream>>,
//                        ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/complex:1529:28: note: while substituting deduced template arguments into function template 'operator<<' [with _Ostream = std::basic_ostream<char> &, _Tp = std::complex<float>]
//   extern template ostream& operator<<(ostream&, const complex<float>&);
//                            ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:137:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_istream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/istream:974:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_istream<char> &> >,
//       std::__is_convertible_to_basic_istream<std::basic_istream<char> &>, std::__is_extractable<std::basic_istream<char> &, std::complex<double> &, void> >' requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Istream>>,
//                        ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/complex:1530:28: note: while substituting deduced template arguments into function template 'operator>>' [with _Istream = std::basic_istream<char> &, _Tp = std::complex<double> &]
//   extern template istream& operator>>(istream&, complex<double>&);
//                            ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:137:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/ostream:685:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >,
//       std::__is_convertible_to_basic_ostream<std::basic_ostream<char> &>, std::__is_insertable<std::basic_ostream<char> &, const std::complex<double> &, void> >' requested
//       here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Ostream>>,
//                        ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/complex:1531:28: note: while substituting deduced template arguments into function template 'operator<<' [with _Ostream = std::basic_ostream<char> &, _Tp = std::complex<double>]
//   extern template ostream& operator<<(ostream&, const complex<double>&);
//                            ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:137:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_istream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/istream:974:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_istream<char> &> >,
//       std::__is_convertible_to_basic_istream<std::basic_istream<char> &>, std::__is_extractable<std::basic_istream<char> &, std::complex<long double> &, void> >' requested
//       here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Istream>>,
//                        ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/complex:1532:28: note: while substituting deduced template arguments into function template 'operator>>' [with _Istream = std::basic_istream<char> &, _Tp = std::complex<long double> &]
//   extern template istream& operator>>(istream&, complex<long double>&);
//                            ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:137:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/ostream:685:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >,
//       std::__is_convertible_to_basic_ostream<std::basic_ostream<char> &>, std::__is_insertable<std::basic_ostream<char> &, const std::complex<long double> &, void> >'
//       requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Ostream>>,
//                        ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/complex:1533:28: note: while substituting deduced template arguments into function template 'operator<<' [with _Ostream = std::basic_ostream<char> &, _Tp = std::complex<long double>]
//   extern template ostream& operator<<(ostream&, const complex<long double>&);
//                            ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:137:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_istream<wchar_t> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/istream:974:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_istream<wchar_t> &> >,
//       std::__is_convertible_to_basic_istream<std::basic_istream<wchar_t> &>, std::__is_extractable<std::basic_istream<wchar_t> &, std::complex<float> &, void> >' requested
//       here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Istream>>,
//                        ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/complex:1536:29: note: while substituting deduced template arguments into function template 'operator>>' [with _Istream = std::basic_istream<wchar_t> &, _Tp = std::complex<float> &]
//   extern template wistream& operator>>(wistream&, complex<float>&);
//                             ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:137:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_ostream<wchar_t> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/ostream:685:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<wchar_t> &> >,
//       std::__is_convertible_to_basic_ostream<std::basic_ostream<wchar_t> &>, std::__is_insertable<std::basic_ostream<wchar_t> &, const std::complex<float> &, void> >'
//       requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Ostream>>,
//                        ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/complex:1537:29: note: while substituting deduced template arguments into function template 'operator<<' [with _Ostream = std::basic_ostream<wchar_t> &, _Tp = std::complex<float>]
//   extern template wostream& operator<<(wostream&, const complex<float>&);
//                             ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:137:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_istream<wchar_t> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/istream:974:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_istream<wchar_t> &> >,
//       std::__is_convertible_to_basic_istream<std::basic_istream<wchar_t> &>, std::__is_extractable<std::basic_istream<wchar_t> &, std::complex<double> &, void> >' requested
//       here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Istream>>,
//                        ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/complex:1538:29: note: while substituting deduced template arguments into function template 'operator>>' [with _Istream = std::basic_istream<wchar_t> &, _Tp = std::complex<double> &]
//   extern template wistream& operator>>(wistream&, complex<double>&);
//                             ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:137:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_ostream<wchar_t> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/ostream:685:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<wchar_t> &> >,
//       std::__is_convertible_to_basic_ostream<std::basic_ostream<wchar_t> &>, std::__is_insertable<std::basic_ostream<wchar_t> &, const std::complex<double> &, void> >'
//       requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Ostream>>,
//                        ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/complex:1539:29: note: while substituting deduced template arguments into function template 'operator<<' [with _Ostream = std::basic_ostream<wchar_t> &, _Tp = std::complex<double>]
//   extern template wostream& operator<<(wostream&, const complex<double>&);
//                             ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:137:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_istream<wchar_t> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/istream:974:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_istream<wchar_t> &> >,
//       std::__is_convertible_to_basic_istream<std::basic_istream<wchar_t> &>, std::__is_extractable<std::basic_istream<wchar_t> &, std::complex<long double> &, void> >'
//       requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Istream>>,
//                        ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/complex:1540:29: note: while substituting deduced template arguments into function template 'operator>>' [with _Istream = std::basic_istream<wchar_t> &, _Tp = std::complex<long double> &]
//   extern template wistream& operator>>(wistream&, complex<long double>&);
//                             ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:137:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_ostream<wchar_t> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/ostream:685:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<wchar_t> &> >,
//       std::__is_convertible_to_basic_ostream<std::basic_ostream<wchar_t> &>, std::__is_insertable<std::basic_ostream<wchar_t> &, const std::complex<long double> &, void> >'
//       requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Ostream>>,
//                        ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/complex:1541:29: note: while substituting deduced template arguments into function template 'operator<<' [with _Ostream = std::basic_ostream<wchar_t> &, _Tp = std::complex<long double>]
//   extern template wostream& operator<<(wostream&, const complex<long double>&);
//                             ^
// In file included from input_line_14:1:
// /home/adamgatt/miniconda3/include/xcpp/xmime.hpp:38:34: error: no viable overloaded '='
//             bundle["text/plain"] = oss.str();
//             ~~~~~~~~~~~~~~~~~~~~ ^ ~~~~~~~~~
// /home/adamgatt/miniconda3/include/nlohmann/json.hpp:18662:17: note: candidate function not viable: no known conversion from 'std::__cxx11::basic_ostringstream<char, std::char_traits<char>, std::allocator<char> >::__string_type' (aka
//       'basic_string<char, std::char_traits<char>, std::allocator<char> >') to 'nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long,
//       unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > >' for 1st argument
//     basic_json& operator=(basic_json other) noexcept (
//                 ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:137:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::__cxx11::basic_ostringstream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/ostream:685:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::__cxx11::basic_ostringstream<char> &> >,
//       std::__is_convertible_to_basic_ostream<std::__cxx11::basic_ostringstream<char> &>, std::__is_insertable<std::basic_ostream<char> &, const long double &, void> >'
//       requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Ostream>>,
//                        ^
// /home/adamgatt/miniconda3/include/xcpp/xmime.hpp:36:17: note: while substituting deduced template arguments into function template 'operator<<' [with _Ostream = std::__cxx11::basic_ostringstream<char> &, _Tp = long double]
//             oss << value;
//                 ^
// /home/adamgatt/miniconda3/include/xcpp/xmime.hpp:64:24: note: in instantiation of function template specialization 'xcpp::detail::mime_bundle_repr_via_sstream<long double>' requested here
//         return detail::mime_bundle_repr_via_sstream(value);
//                        ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:114:31: error: no member named 'value' in 'std::is_function<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       >'
//     : public conditional<_B1::value, _B1, __or_<_B2, _B3, _Bn...>>::type
//                          ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:142:36: note: in instantiation of template class 'std::__or_<std::is_function<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map,
//       std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned
//       char> > > > > >, std::is_reference<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       >, std::is_void<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>,
//       bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > > > >' requested here
//     : public __bool_constant<!bool(_Pp::value)>
//                                    ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:600:14: note: in instantiation of template class 'std::__not_<std::__or_<std::is_function<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > > > >, std::is_reference<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > > > >, std::is_void<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map,
//       std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned
//       char> > > > > > > >' requested here
//     : public __not_<__or_<is_function<_Tp>, is_reference<_Tp>,
//              ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:109:26: note: in instantiation of template class 'std::is_object<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       >' requested here
//     : public conditional<_B1::value, _B1, _B2>::type
//                          ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:637:14: note: in instantiation of template class 'std::__or_<std::is_object<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map,
//       std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned
//       char> > > > > >, std::is_reference<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       > >' requested here
//     : public __or_<is_object<_Tp>, is_reference<_Tp>>::type
//              ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:1021:33: note: in instantiation of template class 'std::__is_referenceable<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map,
//       std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned
//       char> > > > > >' requested here
//   template<typename _Tp, bool = __is_referenceable<_Tp>::value>
//                                 ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:1036:14: note: (skipping 2 contexts in backtrace; use -ftemplate-backtrace-limit=0 to see all)
//     : public __is_copy_assignable_impl<_Tp>
//              ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/stl_pair.h:379:3: note: in instantiation of template class 'std::__and_<std::is_copy_assignable<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > > > >, std::is_copy_assignable<bool> >' requested here
//                 __and_<is_copy_assignable<_T1>,
//                 ^
// /home/adamgatt/miniconda3/include/nlohmann/json.hpp:18124:33: note: in instantiation of template class 'std::pair<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >,
//       bool>' requested here
//                 m_value.object->emplace(
//                                 ^
// /home/adamgatt/miniconda3/include/nlohmann/json.hpp:18316:16: note: in instantiation of member function 'nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator,
//       adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > >::basic_json' requested here
//         return basic_json(init, false, value_t::object);
//                ^
// /home/adamgatt/miniconda3/include/xcpp/xmime.hpp:33:37: note: in instantiation of member function 'nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator,
//       adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > >::object' requested here
//             auto bundle = nl::json::object();
//                                     ^
// /home/adamgatt/miniconda3/include/xcpp/xmime.hpp:64:24: note: in instantiation of function template specialization 'xcpp::detail::mime_bundle_repr_via_sstream<long double>' requested here
//         return detail::mime_bundle_repr_via_sstream(value);
//                        ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:1039:58: error: no member named 'value' in 'std::__is_referenceable<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       >'
//   template<typename _Tp, bool = __is_referenceable<_Tp>::value>
//                                 ~~~~~~~~~~~~~~~~~~~~~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:1054:14: note: in instantiation of default argument for '__is_move_assignable_impl<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map,
//       std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned
//       char> > > > > >' required here
//     : public __is_move_assignable_impl<_Tp>
//              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:132:26: note: in instantiation of template class 'std::is_move_assignable<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map,
//       std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned
//       char> > > > > >' requested here
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/stl_pair.h:390:3: note: in instantiation of template class 'std::__and_<std::is_move_assignable<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > > > >, std::is_move_assignable<bool> >' requested here
//                 __and_<is_move_assignable<_T1>,
//                 ^
// /home/adamgatt/miniconda3/include/nlohmann/json.hpp:18124:33: note: in instantiation of template class 'std::pair<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >,
//       bool>' requested here
//                 m_value.object->emplace(
//                                 ^
// /home/adamgatt/miniconda3/include/nlohmann/json.hpp:18316:16: note: in instantiation of member function 'nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator,
//       adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > >::basic_json' requested here
//         return basic_json(init, false, value_t::object);
//                ^
// /home/adamgatt/miniconda3/include/xcpp/xmime.hpp:33:37: note: in instantiation of member function 'nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator,
//       adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > >::object' requested here
//             auto bundle = nl::json::object();
//                                     ^
// /home/adamgatt/miniconda3/include/xcpp/xmime.hpp:64:24: note: in instantiation of function template specialization 'xcpp::detail::mime_bundle_repr_via_sstream<long double>' requested here
//         return detail::mime_bundle_repr_via_sstream(value);
//                        ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:114:31: error: no member named 'value' in 'std::is_void<const std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       &>'
//     : public conditional<_B1::value, _B1, __or_<_B2, _B3, _Bn...>>::type
//                          ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:1306:19: note: in instantiation of template class 'std::__or_<std::is_void<const std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map,
//       std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned
//       char> > > > > &>, std::is_function<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       >, std::is_array<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       > >' requested here
//            bool = __or_<is_void<_From>, is_function<_To>,
//                   ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:1336:14: note: in instantiation of default argument for '__is_convertible_helper<const std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > > > &, std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       >' required here
//     : public __is_convertible_helper<_From, _To>::type
//              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:132:26: note: in instantiation of template class 'std::is_convertible<const std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map,
//       std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned
//       char> > > > > &, std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       >' requested here
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/stl_pair.h:107:9: note: in instantiation of template class 'std::__and_<std::is_convertible<const std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > > > &, std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       >, std::is_convertible<const bool &, bool> >' requested here
//         return __and_<is_convertible<const _U1&, _T1>,
//                ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/stl_pair.h:258:7: note: in instantiation of function template specialization 'std::_PCC<true, std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > > >, bool>::_ImplicitlyConvertiblePair<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > > >, bool>' requested here
//                            _ImplicitlyConvertiblePair<_U1, _U2>(),
//                            ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/stl_pair.h:260:17: note: (skipping 2 contexts in backtrace; use -ftemplate-backtrace-limit=0 to see all)
//       constexpr pair(const _T1& __a, const _T2& __b)
//                 ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/stl_map.h:575:16: note: in instantiation of function template specialization 'std::_Rb_tree<std::__cxx11::basic_string<char>, std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > >, std::_Select1st<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >,
// ...
//              ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/stl_pair.h:147:9: note: (skipping 4 contexts in backtrace; use -ftemplate-backtrace-limit=0 to see all)
//         return __and_<is_constructible<_T1, _U1&&>,
//                ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/stl_map.h:575:16: note: in instantiation of function template specialization 'std::_Rb_tree<std::__cxx11::basic_string<char>, std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > >, std::_Select1st<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >,
//       std::less<void>, std::allocator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool,
//       long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       >::_M_emplace_unique<std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long,
//       double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > >' requested here
//         { return _M_t._M_emplace_unique(std::forward<_Args>(__args)...); }
//                       ^
// /home/adamgatt/miniconda3/include/nlohmann/json.hpp:18124:33: note: in instantiation of function template specialization 'std::map<std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > >,
//       std::less<void>, std::allocator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool,
//       long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       >::emplace<std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double,
//       std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > >' requested here
//                 m_value.object->emplace(
//                                 ^
// /home/adamgatt/miniconda3/include/nlohmann/json.hpp:18316:16: note: in instantiation of member function 'nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator,
//       adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > >::basic_json' requested here
//         return basic_json(init, false, value_t::object);
//                ^
// /home/adamgatt/miniconda3/include/xcpp/xmime.hpp:33:37: note: in instantiation of member function 'nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator,
//       adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > >::object' requested here
//             auto bundle = nl::json::object();
//                                     ^
// /home/adamgatt/miniconda3/include/xcpp/xmime.hpp:64:24: note: in instantiation of function template specialization 'xcpp::detail::mime_bundle_repr_via_sstream<long double>' requested here
//         return detail::mime_bundle_repr_via_sstream(value);
//                        ^
// In file included from input_line_1:1:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/new:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/exception:144:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/nested_exception.h:40:
// In file included from /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/move.h:55:
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:142:41: error: no member named 'value' in 'std::__and_<std::is_convertible<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map,
//       std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned
//       char> > > > > &&, std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       >, std::is_convertible<const bool &, bool> >'
//     : public __bool_constant<!bool(_Pp::value)>
//                                    ~~~~~^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:132:14: note: in instantiation of template class 'std::__not_<std::__and_<std::is_convertible<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > > > &&, std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       >, std::is_convertible<const bool &, bool> > >' requested here
//     : public conditional<_B1::value, _B2, _B1>::type
//              ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/type_traits:137:14: note: in instantiation of template class 'std::__and_<std::is_constructible<bool, const bool &&>,
//       std::__not_<std::__and_<std::is_convertible<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       &&, std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long,
//       unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > > >, std::is_convertible<const bool &, bool> > >
//       >' requested here
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//              ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/stl_pair.h:147:9: note: in instantiation of template class 'std::__and_<std::is_constructible<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > > >, std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       &&>, std::is_constructible<bool, const bool &&>, std::__not_<std::__and_<std::is_convertible<std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > > > &&, std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       >, std::is_convertible<const bool &, bool> > > >' requested here
//         return __and_<is_constructible<_T1, _U1&&>,
//                ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/stl_pair.h:316:7: note: in instantiation of function template specialization 'std::_PCC<true, std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > > >, bool>::_MoveCopyPair<false, std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > > >, bool>' requested here
//                            _MoveCopyPair<false, _U1, _T2>(),
//                            ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/stl_pair.h:318:27: note: while substituting prior template arguments into non-type template parameter [with _U1 = std::_Rb_tree_iterator<std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > > >]
//        explicit constexpr pair(_U1&& __x, const _T2& __y)
//                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/stl_tree.h:2415:15: note: (skipping 1 context in backtrace; use -ftemplate-backtrace-limit=0 to see all)
//               return _Res(_M_insert_node(__res.first, __res.second, __z), true);
//                      ^
// /home/adamgatt/miniconda3/bin/../lib/gcc/x86_64-conda-linux-gnu/9.3.0/../../../../x86_64-conda-linux-gnu/include/c++/9.3.0/bits/stl_map.h:575:16: note: in instantiation of function template specialization 'std::_Rb_tree<std::__cxx11::basic_string<char>, std::pair<const std::__cxx11::basic_string<char>,
//       nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned
//       char, std::allocator<unsigned char> > > >, std::_Select1st<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >,
//       std::less<void>, std::allocator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool,
//       long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       >::_M_emplace_unique<std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long,
//       double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > >' requested here
//         { return _M_t._M_emplace_unique(std::forward<_Args>(__args)...); }
//                       ^
// /home/adamgatt/miniconda3/include/nlohmann/json.hpp:18124:33: note: in instantiation of function template specialization 'std::map<std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector,
//       std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > >,
//       std::less<void>, std::allocator<std::pair<const std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool,
//       long, unsigned long, double, std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > > >
//       >::emplace<std::__cxx11::basic_string<char>, nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double,
//       std::allocator, adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > > >' requested here
//                 m_value.object->emplace(
//                                 ^
// /home/adamgatt/miniconda3/include/nlohmann/json.hpp:18316:16: note: in instantiation of member function 'nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator,
//       adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > >::basic_json' requested here
//         return basic_json(init, false, value_t::object);
//                ^
// /home/adamgatt/miniconda3/include/xcpp/xmime.hpp:33:37: note: in instantiation of member function 'nlohmann::basic_json<std::map, std::vector, std::__cxx11::basic_string<char>, bool, long, unsigned long, double, std::allocator,
//       adl_serializer, std::vector<unsigned char, std::allocator<unsigned char> > >::object' requested here
//             auto bundle = nl::json::object();
//                                     ^
// /home/adamgatt/miniconda3/include/xcpp/xmime.hpp:64:24: note: in instantiation of function template specialization 'xcpp::detail::mime_bundle_repr_via_sstream<long double>' requested here
//         return detail::mime_bundle_repr_via_sstream(value);
//                        ^
// fatal error: too many errors emitted, stopping now [-ferror-limit=]
// input_line_15:1:7: error: use of undeclared identifier 'xcpp'
// using xcpp::mime_bundle_repr;void __cling_Un1Qu36(void* vpClingValue) {
//       ^
// input_line_15:2:2: error: use of undeclared identifier 'mime_bundle_repr'; did you mean 'xtl::mime_bundle_repr'?
//  mime_bundle_repr(*((bool(*)[7])*(void**)0x7ffe720132b8));
//  ^~~~~~~~~~~~~~~~
//  xtl::mime_bundle_repr
// /home/adamgatt/miniconda3/include/xtl/xbasic_fixed_string.hpp:2371:20: note: 'xtl::mime_bundle_repr' declared here
//     nlohmann::json mime_bundle_repr(const xbasic_fixed_string<CT, N, ST, EP, TR>& str)
//                    ^
// input_line_15:2:2: error: no matching function for call to 'mime_bundle_repr'
//  mime_bundle_repr(*((bool(*)[7])*(void**)0x7ffe720132b8));
//  ^~~~~~~~~~~~~~~~
// /home/adamgatt/miniconda3/include/xtl/xbasic_fixed_string.hpp:2371:20: note: candidate template ignored: could not match 'xbasic_fixed_string<type-parameter-0-0, N, ST, , type-parameter-0-4>' against 'bool [7]'
//     nlohmann::json mime_bundle_repr(const xbasic_fixed_string<CT, N, ST, EP, TR>& str)
//                    ^

// %% [markdown]
// ## explicit (pre-11)

// %% [markdown]
// `explicit`

// %%
class Factor {
    public:
    Factor(double value)
        : value(value) { }
    
    double apply(double input) {
        return input * value;
    }
    
    private:
    double value;
}

// %%
Factor myFactor = 1/5;

myFactor.apply(100)
// Out:
// 0.0000000

// %%
class Factor {
    public:
    // Explicit, no implicit type conversion for copy-initialisation
    explicit Factor(double value)
        : value(value) { }
    
    double apply(double input) {
        return input * value;
    }
    
    private:
    double value;
};

Factor myFactor = 1/5;

myFactor.apply(100)
// Out:
// input_line_12:15:9: error: no viable conversion from 'int' to '__cling_N55::Factor'
//  Factor myFactor = 1/5;
//         ^          ~~~
// input_line_12:1:7: note: candidate constructor (the implicit copy constructor) not viable: no known conversion from 'int' to 'const __cling_N55::Factor &' for 1st argument
// class Factor {
//       ^
// input_line_12:1:7: note: candidate constructor (the implicit move constructor) not viable: no known conversion from 'int' to '__cling_N55::Factor &&' for 1st argument
// class Factor {
//       ^
// Interpreter Error:

// %% [markdown]
// ## Scoped enums

// %% [markdown]
// ## using

// %% [markdown]
// ## auto (in some situations)

// %% [markdown]
// ## Const references (pre-11)

// %% [markdown]
// Despite introducing the useful `nullptr` above, the null reference has been described as its creator as the [Billion Dollar Mistake](https://www.youtube.com/watch?v=YYkOWzrO3xg).
